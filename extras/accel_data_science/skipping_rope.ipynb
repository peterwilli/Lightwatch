# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils.accel_data import parse_accel_logs
import os
import pandas as pd
pd.options.plotting.backend = "plotly"

# %%
logs_file_path = os.path.join("data", "skipping_rope_left_arm_peter.txt")
accel_data = None
with open(logs_file_path) as f:
    logs = f.read()
    accel_data = parse_accel_logs(logs)
accel_data
# Out:
#         X    Y    Z
# 0     477  275 -887
# 1     462  160 -833
# 2     440  145 -881
# 3     439  192 -879
# 4     563  674 -917
# ...   ...  ...  ...
# 1620  266  164 -955
# 1621  274  167 -957
# 1622  273  167 -950
# 1623  268  168 -957
# 1624  270  173 -956
#
# [1625 rows x 3 columns]

# %%
fig = accel_data.plot()
fig.show()
